# %% [markdown]
# # QuadStore project - Data collection
#
# - Many **key features** of the project requires *realistic* games' data in order to function correctly.
# Some of these features are:
#     - Games display.
#     - Filtering system (by Genre,...)
#     - Reccomendation system.
# - As a result, we will collect data from **Steam** - a popular website for purchasing games.
# ---
# **Disclaimer**:
#
# No private data is collected. All data gathered is not prohibited by Steam (robots.txt).
#
# The_Quad team **guarantees** under no circumstances will this data be used for *commercial or unlawful* intentions.

# %% [markdown]
# ## Collection Method
#
# - We will use simple web scraping techniques to collect games data, such as **Selenium, requests**

# %% [markdown]
# ## Metadata
#
# - Our data will have **9 features**:
#     - **Title**: title of the game.
#     - **Release date**: release date of the game.
#     - **Categories**: the main categories that the game belongs to.
#     - **Sub-Categories**: all sub-categories that the game belongs to.
#     - **Price**: Retail price of the game.
#     - **Img url**: Url for the thumbnail image of the game.
#     - **Description**: short description of the game. *(currently unavailable)*
#     - **Rating**: Rating of the game.
#     - **Reviews**: Number of reviews made about the game.

# %% [markdown]
# ### 0. Import necessary libraries

# %%
import requests
from multiprocessing.dummy import Pool
import pandas as pd
import json

# %% [markdown]
# ### 1. Extract categories and sub-categories

# %%
#Collect categories and sub-categories list
with open('./categories.json', 'r') as rstream:
    CATEGORIES = json.load(rstream)
with open('./sub_categories.json', 'r') as rstream:
    SUB_CATEGORIES = json.load(rstream)

# %%
CATEGORIES

# %%
cat_list = CATEGORIES.keys()
sub_cat_list = SUB_CATEGORIES.keys()

# %%
cat_list

# %% [markdown]
# ### 2. Selenium and Scraping
#
# - We will use ```selenium.webdriver``` to handle dynamic javascript content.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from time import sleep

# %% [markdown]
# - Create function to extract necessary data

# %%
def extract_data(game_list, cur_titles, data:list, default_cat):
    for game in game_list:
        title = game.find_element(By.CLASS_NAME, 'salepreviewwidgets_TitleCtn_1F4bc').text
        if title in cur_titles: #Avoid overlapping
            continue
        else:
            cur_titles.append(title)
        img_url = game.find_element(By.TAG_NAME, 'img').get_attribute('src')
        release_date = game.find_element(By.CLASS_NAME, 'salepreviewwidgets_StoreSaleWidgetRelease_3eOdk').text
        try:
            price = game.find_element(By.CLASS_NAME, 'salepreviewwidgets_StoreSalePriceBox_Wh0L8').text.strip('₫')
            if price == "Free To Play":
                price = 0
        except:
            price = 0
        rating = game.find_element(By.CSS_SELECTOR, 'a[class="gamehover_ReviewScore_24NyY ReviewScore Focusable"]').find_elements(By.TAG_NAME, 'div')[1].text
        reviews = game.find_element(By.CLASS_NAME, 'gamehover_ReviewScoreCount_1Deyv').text.strip('|')
        reviews = reviews.strip('User Reviews').strip()
        
        categories = default_cat + ";"
        sub_categories = ""
        cats = game.find_element(By.CLASS_NAME, 'salepreviewwidgets_StoreSaleWidgetTags_3OSJs')
        tags = cats.find_elements(By.TAG_NAME, 'a')
        for tag in tags:
            t = tag.text
            if t == default_cat:
                continue
            if t in cat_list:
                categories += t + ";"
            elif t in sub_cat_list:
                sub_categories += t + ";"
    
        data.append([title,release_date,categories,sub_categories,price,img_url,"dummy desc",rating,reviews])
    return data, cur_titles

# %% [markdown]
# - Prepare some necessary variables

# %%
urls = CATEGORIES.items()
data = []
cur_titles = []

#Initialize and run Chrome browser
options = webdriver.ChromeOptions()
browser = webdriver.Chrome(options=options)
browser.implicitly_wait(5)

# %% [markdown]
# - Start scraping

# %%
#Start scraping
for cat,url in urls:
    print("Scraping: ",url)
    browser.get(url)
    sleep(7)
    
    game_list = browser.find_elements(By.CLASS_NAME,'salepreviewwidgets_SaleItemBrowserRow_y9MSd')
    data, cur_titles = extract_data(game_list, cur_titles, data, cat)

# %% [markdown]
# - Create dataframe and save to csv file

# %%
columns = ['title','release_date','categories','sub_categories','price','img_url','desc','rating','reviews_count']
df = pd.DataFrame(data,columns=columns)

# %%
df.to_csv('games_steam_org.csv')

# %% [markdown]
# ### 3. Preprocessing
#
# - We will encode all *ratings* to numerical values **(ranking from 1-5).**

# %%
df['rating'].unique()

# %%
mapping = {'Overwhelmingly Positive':5,'Very Positive':4,'Mostly Positive':3,'Mixed':2,'Mostly Negative':1,'Overwhelmingly Negative':0}

df['rating'] = df['rating'].map(mapping)

# %%
df.head()

# %%
df.to_csv('games_steam_processed.csv')

# %% [markdown]
# ## (04/12/2023) Recollecting Data
# This section is written to collect extra neccessary features on current data.

# %%
import requests
from multiprocessing.dummy import Pool
import pandas as pd
import json

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from time import sleep

# %%
df = pd.read_csv('../data/processed_data.csv')
df.head()
# Out:
#                title  release_date categories             sub_categories
# 0   COUNTER-STRIKE 2  AUG 22, 2012    Action;               Multiplayer;  \
# 1   EA SPORTS FC™ 24  SEP 28, 2023    Action;                        NaN
# 2      APEX LEGENDS™   NOV 5, 2020    Action;               Multiplayer;
# 3      CALL OF DUTY®  OCT 28, 2022    Action;  Multiplayer;Singleplayer;
# 4  BATTLEFIELD™ 2042  NOV 19, 2021    Action;      Military;Multiplayer;
#
#        price                                            img_url        desc
# 0        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...  dummy desc  \
# 1  1090000.0  https://cdn.cloudflare.steamstatic.com/steam/a...  dummy desc
# 2        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...  dummy desc
# 3        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...  dummy desc
# 4   158500.0  https://cdn.cloudflare.steamstatic.com/steam/a...  dummy desc
#
#    rating  reviews_count
# 0       4        7694152
# 1       2          11131
# 2       3         732521
# 3       2         248663
# 4       2         164144

# %% [markdown]
# ### Extra features to be collected
# - long/short description
# - img_urls
# - videos urls
# - developer

# %%
url = 'https://store.steampowered.com/search/?term='
#search_result_row ds_collapse_flag  app_impression_tracked
dev = []
short_desc = []
long_desc = []
imgs = []
vids = []

options = webdriver.ChromeOptions()
browser = webdriver.Chrome(options=options)
browser.implicitly_wait(3)

for name in df.title:
    name = name.replace(' ','+')
    browser.get(url+name)
    sleep(2)
    
    link = browser.find_element(By.ID, 'search_resultsRows')
    link = link.find_element(By.TAG_NAME, 'a')
    link = link.get_attribute('href')
    browser.get(link)
    sleep(2)
    
    try:
        dev_val = browser.find_element(By.ID, 'developers_list')
    except: #Age restricted
        dev.append(None)
        short_desc.append(None)
        long_desc.append(None)
        imgs.append(None)
        vids.append(None)
        continue
    dev.append(dev_val.text)
    
    try:
        short_desc_val = browser.find_element(By.CLASS_NAME, 'game_description_snippet')
        short_desc.append(short_desc_val.text)
    except:
        short_desc.append(None)
    
    try:
        long_desc_val = browser.find_element(By.CLASS_NAME, 'game_area_description')
        long_desc.append(long_desc_val.text)
    except:
        long_desc.append(None)
    
    try:
        imgs_vals = browser.find_element(By.ID, 'highlight_strip_scroll')
        imgs_vals = imgs_vals.find_elements(By.TAG_NAME, 'img')
        print(len(imgs_vals))
        ivals = ''
        vvals = ''
        text = 'movie'
        for val in imgs_vals:
            val = val.get_attribute('src')
            if val.find(text) != -1:
                vvals += val + ';'
                continue
            vals = vals + val + ';'
        imgs.append(vals)
        vids.append(vvals) if vvals != '' else vids.append(None)
    except:
        imgs.append(None)
# Out:
# 23
# 13
# 10
# 14
# 42
# 6
# 19
# 15
# 33
# 13
# 56
# 7
# 15
# 16
# 44
# 35
# 9
# 25
# 12
# 8
# 12
# 10
# 5
# 25
# 26
# 14
# 14
# 14
# 27
# 8
# 13
# 11
# 18
# 10
# 24
# 152
# 12
# 10
# 95
# 29
# 56
# 20
# 11
# 17
# 19
# 11
# 10
# 18
# 9
# 9
# 16
# 26
# 13
# 12
# 21
# 15
# 18
# 9
# 12
# 21
# 21
# 5
# 8
# 11
# 10
# 14
# 19
# 20
# 10
# 13
# 21
# 14
# 21
# 9
# 4

# %% [markdown]
# Append to Dataframe

# %%
df['developer'] = pd.Series(dev)
df['short_desc'] = pd.Series(short_desc)
df['desc'] = pd.Series(long_desc)
df = df.rename(columns={'img_url':'banner_url'})
df['img_urls'] = pd.Series(imgs)
df['vid_urls'] = pd.Series(vids)
df.head()
# Out:
#                title  release_date categories             sub_categories
# 0   COUNTER-STRIKE 2  AUG 22, 2012    Action;               Multiplayer;  \
# 1   EA SPORTS FC™ 24  SEP 28, 2023    Action;                        NaN
# 2      APEX LEGENDS™   NOV 5, 2020    Action;               Multiplayer;
# 3      CALL OF DUTY®  OCT 28, 2022    Action;  Multiplayer;Singleplayer;
# 4  BATTLEFIELD™ 2042  NOV 19, 2021    Action;      Military;Multiplayer;
#
#        price                                         banner_url
# 0        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...  \
# 1  1090000.0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 2        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 3        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 4   158500.0  https://cdn.cloudflare.steamstatic.com/steam/a...
#
#                                                 desc  rating  reviews_count
# 0  ABOUT THIS GAME\nFor over two decades, Counter...       4        7694152  \
# 1  PLAY NOW FOR A UEFA EURO 2024™ ULTIMATE TEAM™ ...       2          11131
# 2  REVIEWS\n“The champion of Battle Royales.”\n9/...       3         732521
# 3                                               None       2         248663
# 4  MASTER THE UNKNOWN IN BATTLEFIELD™ 2042 – SEAS...       2         164144
#
#                 developer                                         short_desc
# 0                   Valve  For over two decades, Counter-Strike has offer...  \
# 1  EA Canada & EA Romania  EA SPORTS FC™ 24 welcomes you to The World’s G...
# 2   Respawn Entertainment  Apex Legends is the award-winning, free-to-pla...
# 3                    None                                               None
# 4                    DICE  Master the unknown in Season 6: Dark Creations...
#
#                                             img_urls
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...  \
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3                                               None
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                             vid_urls
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...

# %% [markdown]
# Save to csv

# %%
df.to_csv('../data/new_processed_data.csv', index=False)

# %% [markdown]
# # 05/12/2023 (Recollecting Data)
# - We'll collect 'expanded' versions of all images (excluding banner).

# %%
from multiprocessing.dummy import Pool
import pandas as pd
import json

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from time import sleep

# %%
df = pd.read_csv('../data/new_processed_data.csv')
df.head()
# Out:
#                title  release_date categories             sub_categories
# 0   COUNTER-STRIKE 2  AUG 22, 2012    Action;               Multiplayer;  \
# 1   EA SPORTS FC™ 24  SEP 28, 2023    Action;                        NaN
# 2      APEX LEGENDS™   NOV 5, 2020    Action;               Multiplayer;
# 3      CALL OF DUTY®  OCT 28, 2022    Action;  Multiplayer;Singleplayer;
# 4  BATTLEFIELD™ 2042  NOV 19, 2021    Action;      Military;Multiplayer;
#
#        price                                         banner_url
# 0        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...  \
# 1  1090000.0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 2        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 3        0.0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 4   158500.0  https://cdn.cloudflare.steamstatic.com/steam/a...
#
#                                                 desc  rating  reviews_count
# 0  ABOUT THIS GAME\r\nFor over two decades, Count...       4        7694152  \
# 1  PLAY NOW FOR A UEFA EURO 2024™ ULTIMATE TEAM™ ...       2          11131
# 2  REVIEWS\r\n“The champion of Battle Royales.”\r...       3         732521
# 3  CALL OF DUTY®: MODERN WARFARE II\r\nLearn more...       2         248663
# 4  MASTER THE UNKNOWN IN BATTLEFIELD™ 2042 – SEAS...       2         164144
#
#                                           developer
# 0                                             Valve  \
# 1                            EA Canada & EA Romania
# 2                             Respawn Entertainment
# 3  Infinity Ward, Raven Software, Beenox, , , , , ,
# 4                                              DICE
#
#                                           short_desc
# 0  For over two decades, Counter-Strike has offer...  \
# 1  EA SPORTS FC™ 24 welcomes you to The World’s G...
# 2  Apex Legends is the award-winning, free-to-pla...
# 3  Welcome to Call of Duty® HQ, the home of Call ...
# 4  Master the unknown in Season 6: Dark Creations...
#
#                                             img_urls
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...  \
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                             vid_urls
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...

# %%
names = df.title

# %%
options = webdriver.ChromeOptions()
browser = webdriver.Chrome(options=options)
browser.implicitly_wait(3)

# %%
browser.get('https://store.steampowered.com/app/730/CounterStrike_2/')

# %%
img_list = browser.find_element(By.ID, 'highlight_player_area')
img_list = browser.find_elements(By.TAG_NAME, 'img')

# %%
len(img_list)
# Out:
# 113

# %%
df['img_urls'].iloc[2]
# Out:
# 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_796601d9d67faf53486eeb26d0724347cea67ddc.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_d830cfd0550fbb64d80e803e93c929c3abb02056.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_13bb35638c0267759276f511ee97064773b37a51.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_0f8cf82d019c614760fd20801f2bb4001da7ea77.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_ef82850f036dac5772cb07dbc2d1116ea13eb163.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_76f6730dbb911650ba1f41c8e5b4bac638b5beea.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_808cdd373d78c3cf3a78e7026ebb1a15895e0670.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_ef98db5d5a4d877531a5567df082b0fb62d75c80.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_2254a50f27951fb9028bc00b93a7f2ed7aac1e13.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_54b9c26b028c84d5f8a5316f31ae6203953ed84d.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_1b3b5fd437939a7ed00a2155269e78994cb998d3.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_352666c1949ce3966bd966d6ea5a1afd532257bc.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_63d2733b9b4ace01a41d5ba8afd653245d05d54a.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_fe70d46859593aef623a0614f4686e2814405035.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_bb2af3e83ac0385ff2055f2ab9697cdd83e351b7.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_fb8e5e2ae29ce64e2898315c66b5db08989e8f91.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_0db84c628a798e38ca57d69abda119bee1358008.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_18e9ea2715f0407ee05e206073927a648db60d73.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/730/ss_2514675f364079b754b820cbc8b2e7c331d56a26.116x65.jpg?t=1698860631;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_f3d31c7cffc2a6ab42fb76aaac2bc9d5258bc142.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_6c1ef918ffe94050e72dcb2cfad3a95ee3d69f08.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_eb8f5def662f28726c875e641cd5faff75e6b16d.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_96496b17bd35a97ceb926231e963762d3b86c3c8.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_855738ea72e6f90ee0e0b0cedba55848423389e1.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_0f175ec10150f890fe3beb3c8dde3abc2b4c1d62.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_33527a88323cbb39a7c09d7d74955015343efd3f.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_3cb608240d4897f04f0b040eef924470c72856fb.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_b68a973175bebbdf7a189efa43c927899dc95240.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/2195250/ss_5320cc6b6c7fd39b41defe0570c3182df7065fd5.116x65.jpg?t=1701266064;https://cdn.akamai.steamstatic.com/steam/apps/1172470/ss_cdb282ff2b5d0d26e05c2a40a57ff57d0aa73e47.116x65.jpg?t=1700150367;https://cdn.akamai.steamstatic.com/steam/apps/1172470/ss_b93d8cc8bf24eda3abe66a03b7a66c750458bebb.116x65.jpg?t=1700150367;https://cdn.akamai.steamstatic.com/steam/apps/1172470/ss_cb0f3ced72e159a01f1410b17a1e4e61f9a8ed6b.116x65.jpg?t=1700150367;https://cdn.akamai.steamstatic.com/steam/apps/1172470/ss_e1f0cc66a7ec0687c028a25834614b810e9b56a5.116x65.jpg?t=1700150367;https://cdn.akamai.steamstatic.com/steam/apps/117 ...

# %%
for name in names:
